# %%
# !export GEMINI_API_KEY=AIzaSyCdz9Js-HqzE5VB-G72S_yoBwZLoK0KfWE
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Please read the file #file:round_chimaev.mp4 and split it in 30 second windows
import os

media_file = "../../media/round_chimaev.mp4"

assert os.path.exists(media_file), f"Media file {media_file} does not exist."

# %%
# !python3 -m pip install moviepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'moviepy' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'moviepy'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110797 sha256=101bdb99f8843bcc3ef005299b8bd1916b0182bb936aebf98cde1d13d333590b
#   Stored in directory: /home/tenken/.cache/pip/wheels/96/32/2d/e10123bd88fbfc02fed53cc18c80a171d3c87479ed845fa7c1
# Successfully built moviepy
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
# ...

# %%
from moviepy import VideoFileClip

output_dir = "../../media/splits"
os.makedirs(output_dir, exist_ok=True)

clip = VideoFileClip(media_file)
duration = int(clip.duration)

window = 30  # seconds
part = 1

for start in range(0, duration, window):
    end = min(start + window, duration)
    subclip = clip.subclipped(start, end)
    
    output_path = os.path.join(output_dir, f"round_chimaev_part_{part}.mp4")
    subclip.write_videofile(output_path, codec="libx264", audio_codec="aac")
    
    print(f"Created: {output_path}")
    part += 1

print("Done!")
# Out:
# MoviePy - Building video ../../media/splits/round_chimaev_part_1.mp4.
# MoviePy - Writing audio in round_chimaev_part_1TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video ../../media/splits/round_chimaev_part_1.mp4
# MoviePy - Done !
# MoviePy - video ready ../../media/splits/round_chimaev_part_1.mp4
# Created: ../../media/splits/round_chimaev_part_1.mp4
# MoviePy - Building video ../../media/splits/round_chimaev_part_2.mp4.
# MoviePy - Writing audio in round_chimaev_part_2TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video ../../media/splits/round_chimaev_part_2.mp4
# MoviePy - Done !
# MoviePy - video ready ../../media/splits/round_chimaev_part_2.mp4
# Created: ../../media/splits/round_chimaev_part_2.mp4
# MoviePy - Building video ../../media/splits/round_chimaev_part_3.mp4.
# MoviePy - Writing audio in round_chimaev_part_3TEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# MoviePy - Writing video ../../media/splits/round_chimaev_part_3.mp4
# MoviePy - Done !
# ...

# %%
# Striking: jabs, crosses, hooks, footwork
# Defense: blocks, slips, parries, head movement
# Grappling: clinch work
# Submission: takedowns, ground control, submission attempts

# %%
from google import genai
import time

client = genai.Client(api_key="AIzaSyCdz9Js-HqzE5VB-G72S_yoBwZLoK0KfWE")

myfile = client.files.upload(file="../../media/splits/chimaev_whittaker.mp4")#"../../media/splits/round_chimaev_part_5.mp4")

while myfile.state.name == "PROCESSING":
    print('.', end='')
    time.sleep(10)
    myfile = client.files.get(name=myfile.name)

if myfile.state.name == "FAILED":
    raise ValueError(myfile.state.name)
# Out:
# .

# %%
def generate_coach_prompt(role="striking"):
    roles = {
        "striking": {
            "name": "Striking Offense/Defense Analyst",
            "desc": "Análisis enfocado en el intercambio de golpes de pie (Boxeo y Muay Thai).",
            "emphasis": "**posicionamiento** (footwork, ángulo de ataque) y la **conexión efectiva** de golpes.",
            "actions": "Jab/Cross Conectado, Patada (al cuerpo, pierna, cabeza), Knockdown, KO/TKO, Esquive Exitoso, Uso de Finta.",
            "example": """| Tiempo (MM:SS) | Peleador | Acción |
                        | :---: | :---: | :--- |
                        | 00:00 | Burns | Cross Conectado |
                        | 00:01 | Ambos | Intercambio de distancia |
                        | 00:02 | Chimaev | Jab Conectado |
                        | 00:03 | Ambos | Posicionamiento |
                        | 00:04 | Ambos | Reset a centro |
                        | 00:05 | Burns | Patada a pierna conectada |"""
        },
        "grappling": {
            "name": "Grappling Analyst",
            "desc": "Análisis enfocado en el clinch, controles contra la jaula, derribos y trabajo de piso.",
            "emphasis": "**control posicional**, **pases de guardia**, **derribos**, y **defensa de derribo**.",
            "actions": "Takedown efectivo, Defensa de takedown, Control en clinch, Pase de guardia, Ground and pound.",
            "example": """| Tiempo (MM:SS) | Peleador | Acción |
                            | :---: | :---: | :--- |
                            | 00:00 | Ambos | Clinch sin actividad |
                            | 00:01 | Chimaev | Takedown conseguido |
                            | 00:02 | Burns | Intenta defensa de takedown |
                            | 00:03 | Chimaev | Control en suelo |
                            | 00:04 | Ambos | Sin actividad relevante |
                            | 00:05 | Chimaev | Ground and pound |"""
        },
        "submission": {
            "name": "Submission Specialist",
            "desc": "Análisis enfocado en intentos de sumisión, transiciones y defensa.",
            "emphasis": "**intentos de sumisión**, **transiciones entre posiciones**, **escapes**.",
            "actions": "Intento de estrangulación, Intento de palanca, Escape de sumisión, Defensa de sumisión.",
            "example": """| Tiempo (MM:SS) | Peleador | Acción |
                            | :---: | :---: | :--- |
                            | 00:00 | Ambos | Evaluación posicional |
                            | 00:01 | Chimaev | Intento de estrangulación |
                            | 00:02 | Burns | Defensa activa de sumisión |
                            | 00:03 | Burns | Escape |
                            | 00:04 | Chimaev | Cambio a otra sumisión |
                            | 00:05 | Ambos | Sin actividad |"""
        },
        "analista_tactico": {
            "name": "Analista Táctico Integral",
            "desc": "Análisis estratégico de la pelea incluyendo toma de decisiones, estrategia, manejo del tiempo y espacio.",
            "emphasis": "**táctica general**, **patrones de comportamiento**, **ajustes de estrategia**, **lectura del oponente**.",
            "actions": "Cambio de guardia, Presión en jaula, Ajuste de distancia, Cambio de ritmo, Estrategia defensiva.",
            "example": """| Tiempo (MM:SS) | Peleador | Acción |
                            | :---: | :---: | :--- |
                            | 00:00 | Ambos | Estudio de rival |
                            | 00:01 | Burns | Ajusta distancia |
                            | 00:02 | Chimaev | Presiona en jaula |
                            | 00:03 | Ambos | Cambio de guardia |
                            | 00:04 | Ambos | Manejo del ritmo |
                            | 00:05 | Ambos | Sin actividad táctica relevante |"""
        }
    }

    role_key = role.lower()
    if role_key == "analista":
        role_key = "analista_tactico"
    if role_key not in roles:
        raise ValueError(f"Rol '{role}' no soportado. Opciones: {list(roles.keys())}")

    r = roles[role_key]
    prompt = f"""
        **ROL Y OBJETIVO:**
        Eres un **Asistente de Head Coach de MMA**. Tu especialidad es **{r['name']}**. Tu tarea es proporcionar un análisis detallado y estadístico del rendimiento de los dos peleadores en el video.

        * **{r['name']}:**
            * **Descripción de la disciplina:** {r['desc']}
            * **Énfasis:** Se centrará en {r['emphasis']}
            * **Acciones Clave a Tabular:** {r['actions']}

        **INSTRUCCIONES CLAVE PARA LA TABLA:**
        * Genera una tabla de Markdown que registre las acciones clave, acorde al rol elegido.
        * La tabla debe tener exactamente las siguientes tres columnas: **Tiempo (MM:SS)**, **Peleador**, y **Acción**.
        * **IMPORTANTE - SAMPLING CADA 1 SEGUNDO:** Debes registrar una entrada en la tabla **cada 1 segundo** del video (00:00, 00:01, 00:02, 00:03, etc.), independientemente de si ocurre una acción significativa o no.
        * Si en un intervalo de 1 segundo NO ocurre ninguna acción relevante, registra la entrada como:
            * **Peleador:** "Ambos" o el peleador dominante en ese momento
            * **Acción:** Descripción breve del estado (ej. *"Intercambio de distancia"*, *"Posicionamiento"*, *"Clinch sin actividad"*, *"Reset a centro"*, *"Evaluación"*, *"Sin actividad"*)
        * Si en un intervalo de 1 segundo SÍ ocurre una acción relevante, regístrala normalmente con el peleador y la acción específica.
        * El valor de la columna **Tiempo (MM:SS)** debe ser la marca de tiempo en formato **Minuto:Segundo** (ej. `00:00`, `00:01`, `00:02`), alineado a intervalos de 1 segundo.
        * El valor de la columna **Peleador** debe ser el nombre del Peleador A, Peleador B, o "Ambos" según corresponda.
        * El valor de la columna **Acción** debe ser una descripción concisa de la acción o estado relevante (ej. *Jab conectado*, *Patada a pierna*, *Posicionamiento*, *Sin actividad*).

        **EJEMPLO DE TABLA CON SAMPLING CADA 1s:**
        {r['example']}

        **REQUERIMIENTO DE SALIDA:**
        Proporciona la tabla de análisis completa con entradas cada 1 segundo y un breve resumen de los hallazgos principales desde la perspectiva de mi rol elegido.
        """
    return prompt

# Use like this:
# prompt = generate_coach_prompt(role="striking")
# prompt = generate_coach_prompt(role="grappling")
# prompt = generate_coach_prompt(role="submission")
# prompt = generate_coach_prompt(role="analista")


prompt_coach = generate_coach_prompt(role="striking") # cambia aquí el rol a gusto

response = client.models.generate_content(
    model="gemini-2.5-pro", contents=[myfile, prompt_coach], config={
        # "maxOutputTokens": 1500,
        "temperature": 0.0,
        "topP": 0.95,
        "seed": 42,
        # "stopSequences": ["###"]
    }
)

# %%
print(response.text)
# Out:
# Claro, coach. Aquí está el análisis detallado del clip desde la perspectiva de **Striking Offense/Defense**.
#
# ### Análisis de Striking: Whittaker vs. Chimaev
#
# | Tiempo (MM:SS) | Peleador | Acción |
# | :---: | :---: | :--- |
# | 00:00 | Ambos | Evaluación de distancia inicial |
# | 00:01 | Ambos | Posicionamiento en el centro del octágono |
# | 00:02 | Whittaker | Uso de Finta (Jab para medir distancia) |
# | 00:03 | Chimaev | Cierre de distancia explosivo para derribo |
# | 00:04 | Chimaev | Transición de striking a grappling (Intento de derribo) |
# | 00:05 | Ambos | Lucha en la reja (Sin striking) |
# | 00:06 | Chimaev | Control en el clinch contra la reja |
# | 00:07 | Chimaev | Trabajando para asegurar el derribo |
# | 00:08 | Chimaev | Control en el clinch contra la reja |
# | 00:09 | Chimaev | Transición a la espalda de pie |
# | 00:10 | Chimaev | Control en el clinch contra la reja |
# | 00:11 | Chimaev | Trabajando para asegurar el derribo |
# ...

# %%
prompt_coach = generate_coach_prompt(role="grappling") # cambia aquí el rol a gusto

response = client.models.generate_content(
    model="gemini-2.5-pro", contents=[myfile, prompt_coach], config={
        # "maxOutputTokens": 1500,
        "temperature": 0.0,
        "topP": 0.95,
        "seed": 42,
        # "stopSequences": ["###"]
    }
)

print(response.text)
# Out:
# Claro, coach. Aquí tienes el análisis detallado del primer segmento del round desde la perspectiva de un especialista en grappling.
#
# ### **Análisis de Grappling: Whittaker vs. Chimaev (Round 1)**
#
# | Tiempo (MM:SS) | Peleador | Acción |
# |:---:|:---:|:---|
# | 00:00 | Ambos | Evaluación de distancia |
# | 00:01 | Ambos | Posicionamiento en el centro |
# | 00:02 | Chimaev | Cierra la distancia agresivamente |
# | 00:03 | Chimaev | **Intento de Takedown (Double Leg)** |
# | 00:04 | Whittaker | **Defensa de Takedown (Sprawl)** |
# | 00:05 | Chimaev | Presión continua, empuja contra la jaula |
# | 00:06 | Chimaev | **Control en Clinch (Body Lock)** |
# | 00:07 | Whittaker | Defensa contra la jaula, buscando base |
# | 00:08 | Chimaev | Intento de levantar para derribo |
# | 00:09 | Chimaev | Ajusta agarre y levanta a Whittaker |
# | 00:10 | Chimaev | **Takedown Efectivo (Slam parcial)** |
# | 00:11 | Chimaev | Transición inmediata a la espalda |
# ...

# %%
prompt_coach = generate_coach_prompt(role="submission") # cambia aquí el rol a gusto

response = client.models.generate_content(
    model="gemini-2.5-pro", contents=[myfile, prompt_coach], config={
        # "maxOutputTokens": 1500,
        "temperature": 0.0,
        "topP": 0.95,
        "seed": 42,
        # "stopSequences": ["###"]
    }
)

print(response.text)
# Out:
# Claro, coach. Aquí está el análisis detallado del primer segmento del asalto, enfocado en el grappling y las sumisiones.
#
# ### Análisis de Grappling y Sumisión: Whittaker vs. Chimaev
#
# | Tiempo (MM:SS) | Peleador | Acción |
# | :---: | :---: | :--- |
# | 00:00 | Ambos | Evaluación de distancia |
# | 00:01 | Ambos | Posicionamiento inicial |
# | 00:02 | Chimaev | Finta y cierre de distancia |
# | 00:03 | Chimaev | Inicio de derribo (Double Leg) |
# | 00:04 | Whittaker | Defensa de derribo (Sprawl) |
# | 00:05 | Chimaev | Transición a la espalda durante el derribo |
# | 00:06 | Chimaev | Asegura control de la espalda de pie |
# | 00:07 | Whittaker | Intento de giro para escapar del control |
# | 00:08 | Chimaev | Arrastra a Whittaker al suelo manteniendo la espalda |
# | 00:09 | Chimaev | Establece control de espalda en el suelo |
# | 00:10 | Whittaker | Defensa de posición, controlando las manos |
# | 00:11 | Chimaev | Ajusta el control, buscando meter los ganchos |
# ...

# %% [markdown]
# # New Flow
# image.png
